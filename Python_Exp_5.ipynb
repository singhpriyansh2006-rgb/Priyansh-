# %% [markdown]
# <a href="https://colab.research.google.com/github/singhpriyansh2006-rgb/Priyansh-/blob/main/Python_Exp_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Name-Priyansh Singh**
#
# **Sap Id-590029118**
#
# **wn EXPERIMENT 5: LISTS, TUPLES,DICTIONARY**

# %%
#1. scan n values in range 0-3 and print the number of times each value has ocurred.
n = int(input("enter a number:"))
values = []
for i in range (n):
   val = int(input("enter a value:( 0 - 3):"))
   values.append(val)
for i in range(4):
   print(f"{i} occured {values.count(i)}times")
# Out:
# enter a number:8
# enter a value:( 0 - 3):2
# enter a value:( 0 - 3):6
# enter a value:( 0 - 3):4
# enter a value:( 0 - 3):7
# enter a value:( 0 - 3):5
# enter a value:( 0 - 3):1
# enter a value:( 0 - 3):7
# enter a value:( 0 - 3):6
# 0 occured 0times
# 1 occured 1times
# 2 occured 1times
# 3 occured 0times

# %%
#2.Create n tuple to store n numeric values and find average of all values.
n = int(input("Enter how many numbers: "))
values = []
for i in range(n):
    num = int(input("Enter a number: "))
    values.append(num)
    numbers = tuple(values)
    average = sum(numbers) / n
    print("Tuple:", numbers)
    print("Average:", average)
# Out:
# Enter how many numbers: 5
# Enter a number: 3
# Tuple: (3,)
# Average: 0.6
# Enter a number: 7
# Tuple: (3, 7)
# Average: 2.0
# Enter a number: 4
# Tuple: (3, 7, 4)
# Average: 2.8
# Enter a number: 8
# Tuple: (3, 7, 4, 8)
# Average: 4.4
# Enter a number: 1
# Tuple: (3, 7, 4, 8, 1)
# Average: 4.6

# %%
#3.WAP to input a list of scores for N students for N students in data type. Find the score of the runner up and print the output.
num = int(input("Enter the number of students: "))
scores = []
for i in range(num):
    n = int(input("Enter the score: "))
    scores.append(n)
    t = tuple(scores)
    avg = sum(t) / len(t)
    print("The average of tuple items is:",avg)
# Out:
# Enter the number of students: 7
# Enter the score: 44
# The average of tuple items is: 44.0
# Enter the score: 78
# The average of tuple items is: 61.0
# Enter the score: 13
# The average of tuple items is: 45.0
# Enter the score: 69
# The average of tuple items is: 51.0
# Enter the score: 45
# The average of tuple items is: 49.8
# Enter the score: 78
# The average of tuple items is: 54.5
# Enter the score: 89
# The average of tuple items is: 59.42857142857143

# %%
#4.Create a dictionary of n persons where key is name and value is city. a) Display all names b) Display all city names c) Display student
#name and city of all students. d) count number of students in each of all students
n = int(input("Enter number of students: "))
students = {}
for _ in range(n):
    students[input("Name: ")] = input("City: ")
    print("Names:", list(students.keys()))
    print("Cities:", list(students.values()))
    print("Name and City:")
for k, v in students.items():
    print(k, "-", v)
    city_count = {}
for city in students.values():
    city_count[city] = city_count.get(city, 0) + 1
    print("City count:", city_count)
# Out:
# Enter number of students: 3
# City: 5
# Name: Avi
# Names: ['Avi']
# Cities: ['5']
# Name and City:
# City: mumbai
# Name: priyansh
# Names: ['Avi', 'priyansh']
# Cities: ['5', 'mumbai']
# Name and City:
# City: mausam
# Name: 1
# Names: ['Avi', 'priyansh', '1']
# Cities: ['5', 'mumbai', 'mausam']
# Name and City:
# Avi - 5
# priyansh - mumbai
# 1 - mausam
# City count: {'5': 1}
# City count: {'5': 1, 'mumbai': 1}
# City count: {'5': 1, 'mumbai': 1, 'mausam': 1}

# %%
#5.Store details of n movies in a dictionary by taking input from the user. Each movie must store details like name, year, director name ,
#production cost , collection made (earning) and perform the following :-
movies = {}
n = int(input("Enter number of movies: "))
for i in range(n):
    print(f"\nEnter details for movie {i+1}")
    name = input("Movie Name: ")
    year = int(input("Release Year: "))
    director = input("Director Name: ")
    cost = float(input("Production Cost: "))
    collection = float(input("Collection Made: "))

movies[name] = {
"year": year,
"director": director,
"cost": cost,
"collection": collection
}
print("\n--- All Movie Details ---")
for name, details in movies.items():
    print(f"\nMovie: {name}")
    print(f"Year: {details['year']}")
    print(f"Director: {details['director']}")
# Out:
# Enter number of movies: 1
#
# Enter details for movie 1
# Movie Name: la la land
# Release Year: 2017
# Director Name: ryan
# Production Cost: 12
# Collection Made: 15
#
# --- All Movie Details ---
#
# Movie: la la land
# Year: 2017
# Director: ryan
